# %%
import os

# %%
jobs = [
"as-jet-train-job-30-curriculum",
"as-jet-train-job-30-icp",
"as-jet-train-job-30-icp-curriculum",
"as-jet-train-job-30-icp-hyperbolic",
"as-jet-train-job-g30-baseline",
"as-jet-train-job-g30-curriculum",
"as-jet-train-job-g30-icp-curriculum",
"as-jet-train-job-g30-icp",
]
for job in jobs:
    os.system(f"kubectl delete job {job.strip()}")
# Out:
# job.batch "as-jet-train-job-30-curriculum" deleted from cms-ml namespace
# job.batch "as-jet-train-job-30-icp" deleted from cms-ml namespace
# job.batch "as-jet-train-job-30-icp-curriculum" deleted from cms-ml namespace
# job.batch "as-jet-train-job-30-icp-hyperbolic" deleted from cms-ml namespace
# job.batch "as-jet-train-job-g30-baseline" deleted from cms-ml namespace
# job.batch "as-jet-train-job-g30-curriculum" deleted from cms-ml namespace
# job.batch "as-jet-train-job-g30-icp-curriculum" deleted from cms-ml namespace
# job.batch "as-jet-train-job-g30-icp" deleted from cms-ml namespace

# %%
import os
paths = [
    # "nrp/as-jet-train-job-g30-icp.yaml",
    # "nrp/as-jet-train-job-30-icp.yaml",
    # "nrp/as-jet-train-job-30-icp-hyperbolic.yaml",
    "nrp/as-jet-cache-icp-30.yaml"
    # "nrp/as-jet-train-job-150-icp-hyperbolic.yaml",
    # "nrp/as-jet-train-job-150-icp.yaml",
    # "nrp/as-jet-train-job-150-icp-curriculum.yaml"
    # "nrp/as-jet-train-job-g30-icp-hyperbolic.yaml"
]
for path in paths:
    command = f"kubectl create -f {path}"
    os.system(command)
# Out:
# job.batch/as-jet-cache-icp-30 created

# %%
import os
paths = [
    "2026-03-27_10-06-27--bc5696dc-6139-4b66-9916-102fbc6c13ec-a30-polar-icp-hyperbolic"
]
for path in paths:
    job_name = os.path.basename(path)
    print(f"{job_name}")
    os.system(f"mkdir -p downloaded_outputs/{job_name}")
    # os.system(f"mkdir -p downloaded_outputs/{job_name}/vf_viz_cfg")
    # os.system(f"mkdir -p downloaded_outputs/{job_name}/vf_viz_nocfg")
    # command = f"kubectl cp 'as-jet-debug-pod:{path}/train/vf_viz_cfg' 'downloaded_outputs/{job_name}/vf_viz_cfg'"
    # command = f"kubectl cp 'as-jet-debug-pod:{path}/train/vf_viz_nocfg' 'downloaded_outputs/{job_name}/vf_viz_nocfg'"
    command = f"kubectl cp 'as-jet-debug-pod:mnt/data/output/{job_name}' 'downloaded_outputs/{job_name}'"
    command = f"kubectl cp 'as-jet-debug-pod:mnt/data/output/{job_name}' 'downloaded_outputs/{job_name}'"
    os.system(command)
# Out:
# 2026-03-27_10-06-27--bc5696dc-6139-4b66-9916-102fbc6c13ec-a30-polar-icp-hyperbolic
# Defaulted container "debug" out of: debug, setup-env (init)

# %%
import os
paths = [
    "2026-03-27_10-06-27--bc5696dc-6139-4b66-9916-102fbc6c13ec-a30-polar-icp-hyperbolic"
]
for path in paths:
    job_name = os.path.basename(path)
    cmds = [
        f"ffmpeg -r 30 -i downloaded_outputs/{job_name}/train/vf_viz_cfg/field_vectors_%01d.png -vcodec mpeg4 -y downloaded_outputs/{job_name}/train/vf_viz_cfg/movie_zoomed_out.mp4",
        f"ffmpeg -r 30 -i downloaded_outputs/{job_name}/train/vf_viz_nocfg/field_vectors_%01d.png -vcodec mpeg4 -y downloaded_outputs/{job_name}/train/vf_viz_nocfg/movie_zoomed_out.mp4",

        f"ffmpeg -r 30 -i downloaded_outputs/{job_name}/train/vf_viz_cfg/field_vectors_zoomed_%01d.png -vcodec mpeg4 -y downloaded_outputs/{job_name}/train/vf_viz_cfg/movie_zoomed_in.mp4",
        f"ffmpeg -r 30 -i downloaded_outputs/{job_name}/train/vf_viz_nocfg/field_vectors_zoomed_%01d.png -vcodec mpeg4 -y downloaded_outputs/{job_name}/train/vf_viz_nocfg/movie_zoomed_in.mp4",
    ]
    for cmd in cmds:
        os.system(cmd)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.6.3.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gpl --enable-libsvtav1 --enable-libopus --enable-libx264 --enable-libmp3lame --enable-libdav1d --enable-libvpx --enable-libx265 --enable-openssl --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, image2, from 'downloaded_outputs/2026-03-27_10-06-27--bc5696dc-6139-4b66-9916-102fbc6c13ec-a30-polar-icp-hyperbolic/train/vf_viz_cfg/field_vectors_%01d.png':
# ...

# %%
# !kubectl cp 'as-jet-debug-pod:/mnt/data/output/2026-02-18_05-28-14--e00b159c-c425-41c2-8cbc-74d272507dbe-a30-polar-baseline/train/samples/pt_comparison.png' 'downloaded_outputs/2026-02-18_05-28-14--e00b159c-c425-41c2-8cbc-74d272507dbe-a30-polar-baseline/pt_comparison.png'
# Out:
# Defaulted container "debug" out of: debug, setup-env (init)
# tar: Removing leading `/' from member names
# tar: /mnt/data/output/2025-11-14_13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual/train/vf_viz: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors

# %% [markdown]
# ## Download outputs

# %%
kube

# %%
paths = """2025-10-27_01-27-26--46a20bfd-6e52-491d-a470-d9caf6f442f2-gqt30-residual
2025-10-27_01-28-57--9a57e634-f142-4f52-8a79-21403347dcf4-g30-noresidual
2025-10-27_01-28-57--ef77cae3-147a-434f-a205-a220f0d02d28-g30-residual
2025-10-29_08-33-40--9b7242aa-f88d-4ceb-82e1-bccc5ac8f3a5-gqt150-residual""".split("\n")
paths
# Out:
# ['2025-10-27_01-27-26--46a20bfd-6e52-491d-a470-d9caf6f442f2-gqt30-residual',
#  '2025-10-27_01-28-57--9a57e634-f142-4f52-8a79-21403347dcf4-g30-noresidual',
#  '2025-10-27_01-28-57--ef77cae3-147a-434f-a205-a220f0d02d28-g30-residual',
#  '2025-10-29_08-33-40--9b7242aa-f88d-4ceb-82e1-bccc5ac8f3a5-gqt150-residual']

# %%
root_server_path = "as-jet-debug-pod:/mnt/data/output/"
root_download_path = "downloaded_output/"

# %%
import os
for path in paths:
    command = f"kubectl cp {root_server_path}{path} {root_download_path}{path}"
    os.system(command)
# Out:
# Defaulted container "debug" out of: debug, setup-env (init)
# tar: Removing leading `/' from member names
# Defaulted container "debug" out of: debug, setup-env (init)
# tar: Removing leading `/' from member names

# %% [markdown]
# ## Clean outputs

# %%
# all_paths = """./2025-08-21_16-45-34--d813b0ce-692d-428b-aa53-81119cc999c3
# ./2025-08-21_16-45-34--d813b0ce-692d-428b-aa53-81119cc999c3/train
# ./2025-08-21_16-45-34--d813b0ce-692d-428b-aa53-81119cc999c3/train/models
# ./2025-08-21_16-45-34--d813b0ce-692d-428b-aa53-81119cc999c3/data
# ./2025-08-22_18-54-30--aca7249b-3dc3-4155-a47d-49c6a13f52d8
# ./2025-08-22_18-54-30--aca7249b-3dc3-4155-a47d-49c6a13f52d8/jet_attr_model
# ./2025-08-22_18-54-30--aca7249b-3dc3-4155-a47d-49c6a13f52d8/data
# ./2025-08-23_00-37-52--04c4fa7f-2d75-43eb-adcc-d0999125deae
# ./2025-08-23_00-37-52--04c4fa7f-2d75-43eb-adcc-d0999125deae/jet_attr_model
# ./2025-08-23_00-37-52--04c4fa7f-2d75-43eb-adcc-d0999125deae/data
# ./2025-08-23_00-34-17--9a89870e-eee0-487e-bf1f-d66c7a51515e
# ./2025-08-23_00-34-17--9a89870e-eee0-487e-bf1f-d66c7a51515e/jet_attr_model
# ./2025-08-23_00-34-17--9a89870e-eee0-487e-bf1f-d66c7a51515e/data
# ./2025-08-13_20-00-09--cd283497-857d-4917-9a09-03f68e45330c/train
# ./2025-08-13_20-00-09--cd283497-857d-4917-9a09-03f68e45330c/train/vf_viz
# ./2025-08-13_20-00-09--cd283497-857d-4917-9a09-03f68e45330c/train/models
# ./2025-08-13_20-00-09--cd283497-857d-4917-9a09-03f68e45330c/data
# ./2025-08-14_04-29-51--ecd43a2e-a093-46c5-9b13-c6f2828c4ae6/train
# ./2025-08-14_04-29-51--ecd43a2e-a093-46c5-9b13-c6f2828c4ae6/train/vf_viz
# ./2025-08-14_04-29-51--ecd43a2e-a093-46c5-9b13-c6f2828c4ae6/train/models
# ./2025-08-14_04-29-51--ecd43a2e-a093-46c5-9b13-c6f2828c4ae6/vf_viz
# ./2025-08-14_04-29-51--ecd43a2e-a093-46c5-9b13-c6f2828c4ae6/data
# ./2025-08-22_04-41-25--fcc604a6-979e-481c-a352-29cc27a23d5a
# ./2025-08-23_19-22-33--f7bbbb0e-0d7c-4361-995c-c72d7e2f0cbc/train/models
# ./2025-08-23_19-22-33--f7bbbb0e-0d7c-4361-995c-c72d7e2f0cbc/train/vf_viz_nocfg
# ./2025-08-23_19-22-33--f7bbbb0e-0d7c-4361-995c-c72d7e2f0cbc/jet_attr_model
# ./2025-08-23_19-22-33--f7bbbb0e-0d7c-4361-995c-c72d7e2f0cbc/data
# ./2025-08-21_20-46-19--c13d9615-4978-491c-9b70-94461e8594ac
# ./2025-08-21_20-46-19--c13d9615-4978-491c-9b70-94461e8594ac/jet_attr_model
# ./2025-08-21_20-46-19--c13d9615-4978-491c-9b70-94461e8594ac/data
# ./2025-08-18_05-17-06--b62dfcc9-c380-44eb-ad7b-7902594df238/train
# ./2025-08-18_05-17-06--b62dfcc9-c380-44eb-ad7b-7902594df238/train/vf_viz
# ./2025-08-18_05-17-06--b62dfcc9-c380-44eb-ad7b-7902594df238/train/models
# ./2025-08-18_05-17-06--b62dfcc9-c380-44eb-ad7b-7902594df238/data
# ./2025-08-15_20-02-09--7641a493-fb27-4539-90ad-a3be8ec427b2/train
# ./2025-08-15_20-02-09--7641a493-fb27-4539-90ad-a3be8ec427b2/train/vf_viz
# ./2025-08-15_20-02-09--7641a493-fb27-4539-90ad-a3be8ec427b2/train/models
# ./2025-08-15_20-02-09--7641a493-fb27-4539-90ad-a3be8ec427b2/data
# ./2025-08-21_22-44-28--32f2a401-d2be-4d7e-be47-2306a1d62981
# ./2025-08-21_22-44-28--32f2a401-d2be-4d7e-be47-2306a1d62981/jet_attr_model
# ./2025-08-21_22-44-28--32f2a401-d2be-4d7e-be47-2306a1d62981/data
# ./2025-08-23_03-36-52--03da4615-44aa-4ca9-bb7c-757682e08862
# ./2025-08-23_03-36-52--03da4615-44aa-4ca9-bb7c-757682e08862/train
# ./2025-08-23_03-36-52--03da4615-44aa-4ca9-bb7c-757682e08862/train/models
# ./2025-08-23_03-36-52--03da4615-44aa-4ca9-bb7c-757682e08862/jet_attr_model
# ./2025-08-23_03-36-52--03da4615-44aa-4ca9-bb7c-757682e08862/data
# ./2025-08-22_21-53-28--b6447113-54bf-4fcc-91b2-4076e3732922
# ./2025-08-22_21-53-28--b6447113-54bf-4fcc-91b2-4076e3732922/jet_attr_model
# ./2025-08-22_21-53-28--b6447113-54bf-4fcc-91b2-4076e3732922/data""".replace("./", "").splitlines()

# %%
import pickle
import os
from util.metrics import run_save_metrics

with open(f"local_out/2025-11-13_17-21-10--local-run-pod-DBB4D84C-05B8-410A-B892-E7675C7C5BE0/data/x_test.pkl", "rb") as f:
    X_test = pickle.load(f)

# %%
import torch
samples_path = "downloaded_outputs/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual/samples"
samples = []
for f in os.scandir(samples_path):
    if f.name.endswith(".pt"):
        samples.append(torch.load(f.path, map_location="cpu"))
samples
# Out:
# [tensor([[[ 50.0847,  10.3272,   4.6199,  19.3939],
#           [ 50.0847, -10.3272,  -4.6199, -19.3939],
#           [ 49.9036, -12.1904,   3.4366,  18.6028],
#           ...,
#           [ 62.2559,  -1.8829, -35.6738,  14.1048],
#           [ 56.6433, -16.7524, -20.0140,  17.7348],
#           [ 56.6433,  16.7524,  20.0140, -17.7348]],
#
#          [[ 49.9073,  -3.1580,   6.9408,  21.1279],
#           [ 49.9073,   3.1580,  -6.9408, -21.1279],
#           [ 54.7601,  23.5324,  13.5333,  -6.9712],
#           ...,
#           [ 54.9879,  25.6181,   0.3247, -11.8376],
#           [ 47.9773,   0.9561,  12.1737,  16.3107],
#           [ 47.9773,  -0.9561, -12.1737, -16.3107]],
#
#          [[ 48.2910, -10.2069, -19.1878,  -1.9563],
#           [ 48.2910,  10.2069,  19.1878,   1.9563],
#           [ 42.7461,   0.6943,  -1.0592,  14.8069],
#           ...,
#           [ 50.0443, -20.2820,  -6.4740, -16.9408],
#           [ 58.1000,  19.8924,   0.5194,  34.6366],
# ...

# %%
samples = torch.cat(samples, dim=0)
samples.shape
# Out:
# torch.Size([50000, 30, 4])

# %%
# Load X_test
import pickle
from util.metrics import run_save_metrics

with open(f"local_out/2025-11-13_17-21-10--local-run-pod-DBB4D84C-05B8-410A-B892-E7675C7C5BE0/data/x_test.pkl", "rb") as f:
    X_test = pickle.load(f)

# Load samples
import torch
samples_path = "downloaded_outputs/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual/samples"
samples = []
for f in os.scandir(samples_path):
    if f.name.endswith(".pt"):
        samples.append(torch.load(f.path, map_location="cpu"))
samples = torch.cat(samples, dim=0)

# Convert samples from Cartesian to relative polar coordinates
from jetnet.utils import EtaPhiPtE_to_relEtaPhiPt, cartesian_to_EtaPhiPtE

device = 'cpu'
# Convert Cartesian samples to absolute polar coordinates
gen_polar_abs = cartesian_to_EtaPhiPtE(samples.to(device))
gen_polar_abs[:, :, 1] += torch.pi  # Adjust phi to match expected range

# Convert to relative polar coordinates (to match X_test format)
gen_polar_rel = EtaPhiPtE_to_relEtaPhiPt(gen_polar_abs)

# Now run metrics with both in the same coordinate system
eval_info = run_save_metrics(
    X_test=X_test, 
    gen_samples=samples,  # Use converted samples instead of raw Cartesian
    jet_types=['g'], 
    output_path="downloaded_outputs/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual"
)
# Out:
# Calculating cov and mmd over 10 batches: 100%|██████████| 10/10 [00:00<00:00, 29.15it/s]
# Cov MMD: (0.215, 10641167.756759)
# /Users/arjunsharma/development/s25-fermilab-research/src/venv/lib/python3.10/site-packages/numpy/lib/function_base.py:1452: RuntimeWarning: invalid value encountered in subtract
#   a = op(a[slice1], a[slice2])
# Metrics saved to downloaded_outputs/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual/metrics.csv and downloaded_outputs/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual/eval_info.pkl

# %%
import os
import pickle
import torch
import matplotlib.pyplot as plt
from util.metrics import run_save_metrics
from jetnet.utils import EtaPhiPtE_to_relEtaPhiPt, cartesian_to_EtaPhiPtE

# Configuration
X_TEST_PATH = "local_out/2025-11-13_17-21-10--local-run-pod-DBB4D84C-05B8-410A-B892-E7675C7C5BE0/data/x_test.pkl"
SAMPLES_PATH = "downloaded_output/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual/samples"
OUTPUT_PATH = "downloaded_output/2025-11-14__13-16-24--f0519f75-8ee9-46d1-97f7-232d205d1d13-g30-residual"

# Load X_test
with open(X_TEST_PATH, "rb") as f:
    X_test = pickle.load(f)

# Load all sample files
samples = []
for f in os.scandir(SAMPLES_PATH):
    if f.name.endswith(".pt"):
        samples.append(torch.load(f.path, map_location="cpu"))
samples = torch.cat(samples, dim=0)

print(f"X_test shape: {X_test[:][0].shape}")
print(f"Samples shape (Cartesian): {samples.shape}")

# Run metrics (function expects Cartesian coordinates)
eval_info = run_save_metrics(
    X_test=X_test, 
    gen_samples=samples,  # Pass Cartesian - function will convert internally
    jet_types=['g'], 
    output_path=OUTPUT_PATH
)

print("\n=== Evaluation Metrics ===")
for key, value in eval_info.items():
    print(f"{key}: {value}")

# Convert for plotting comparisons
device = 'cpu'
gen_polar_abs = cartesian_to_EtaPhiPtE(samples.to(device))
gen_polar_abs[:, :, 1] += torch.pi
gen_polar_rel = EtaPhiPtE_to_relEtaPhiPt(gen_polar_abs)

# Convert X_test to absolute polar for comparison
def x_test_to_abs(X_test, device='cpu'):
    jet_eta = (X_test[:][1][:, 0]).unsqueeze(1)
    jet_phi_vals = (2 * torch.pi) * torch.rand(len(X_test)).unsqueeze(1)
    jet_pt_ec = X_test[:][1][:, 1:3]
    jet_features = torch.concat([jet_eta, jet_phi_vals, jet_pt_ec], dim=-1)
    eta_rel, phi_rel, pt_rel = torch.unbind(X_test[:][0][:, :, :3], axis=-1)
    Eta, Phi, Pt, _ = torch.unbind(jet_features, axis=-1)

    pt = pt_rel * Pt.unsqueeze(1)
    eta = eta_rel + Eta.unsqueeze(1)
    phi = phi_rel + Phi.unsqueeze(1)
    p0 = pt * torch.cosh(eta)

    return torch.stack([eta, phi, pt, p0], dim=-1).to(device)

test_polar_abs = x_test_to_abs(X_test=X_test, device=device)
test_polar_rel = EtaPhiPtE_to_relEtaPhiPt(test_polar_abs)

# Create comparison plots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Real vs Generated Jet Distributions', fontsize=16)

# Relative coordinates (what metrics use)
features = ['η_rel', 'φ_rel', 'p_T_rel']
for idx, (ax, feature) in enumerate(zip(axes[0], features)):
    ax.hist(test_polar_rel[:, :, idx].flatten().numpy(), bins=100, 
            alpha=0.5, label='Real', density=True)
    ax.hist(gen_polar_rel[:, :, idx].flatten().numpy(), bins=100, 
            alpha=0.5, label='Generated', density=True)
    ax.set_xlabel(feature)
    ax.set_ylabel('Density')
    ax.legend()
    ax.set_title(f'{feature} (Relative)')

# Absolute coordinates
abs_features = ['η', 'φ', 'p_T']
for idx, (ax, feature) in enumerate(zip(axes[1], abs_features)):
    ax.hist(test_polar_abs[:, :, idx].flatten().numpy(), bins=100, 
            alpha=0.5, label='Real', density=True)
    ax.hist(gen_polar_abs[:, :, idx].flatten().numpy(), bins=100, 
            alpha=0.5, label='Generated', density=True)
    ax.set_xlabel(feature)
    ax.set_ylabel('Density')
    ax.legend()
    ax.set_title(f'{feature} (Absolute)')

plt.tight_layout()
plt.savefig(f"{OUTPUT_PATH}/distribution_comparison.png", dpi=300, bbox_inches='tight')
plt.show()

# Jet-level features comparison
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle('Jet-Level Features', fontsize=16)

# Number of particles per jet
real_mask = (test_polar_rel[:, :, 2] > 0).sum(dim=1)
gen_mask = (gen_polar_rel[:, :, 2] > 0).sum(dim=1)

axes[0].hist(real_mask.numpy(), bins=30, alpha=0.5, label='Real', density=True)
axes[0].hist(gen_mask.numpy(), bins=30, alpha=0.5, label='Generated', density=True)
axes[0].set_xlabel('Number of Particles')
axes[0].set_ylabel('Density')
axes[0].legend()
axes[0].set_title('Particle Multiplicity')

# Total jet pT
real_jet_pt = test_polar_abs[:, :, 2].sum(dim=1)
gen_jet_pt = gen_polar_abs[:, :, 2].sum(dim=1)

axes[1].hist(real_jet_pt.numpy(), bins=50, alpha=0.5, label='Real', density=True)
axes[1].hist(gen_jet_pt.numpy(), bins=50, alpha=0.5, label='Generated', density=True)
axes[1].set_xlabel('Total Jet p_T')
axes[1].set_ylabel('Density')
axes[1].legend()
axes[1].set_title('Total Jet Transverse Momentum')

plt.tight_layout()
plt.savefig(f"{OUTPUT_PATH}/jet_features.png", dpi=300, bbox_inches='tight')
plt.show()

print(f"\nPlots saved to {OUTPUT_PATH}/")
# Out:
# X_test shape: torch.Size([53176, 30, 4])
# Samples shape (Cartesian): torch.Size([50000, 30, 4])
# Calculating cov and mmd over 10 batches: 100%|██████████| 10/10 [00:00<00:00, 33.42it/s]
# Cov MMD: (0.23900000000000002, 11070644.082158247)
# python(20736) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20737) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20738) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20739) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20740) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20741) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(20742) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...

# %%
# Add diagnostic code to check the conversion

# Check raw Cartesian samples
print("=== RAW CARTESIAN SAMPLES ===")
print(f"x: min={samples[:,:,0].min():.4f}, max={samples[:,:,0].max():.4f}")
print(f"y: min={samples[:,:,1].min():.4f}, max={samples[:,:,1].max():.4f}")
print(f"z: min={samples[:,:,2].min():.4f}, max={samples[:,:,2].max():.4f}")

# Check after cartesian_to_EtaPhiPtE conversion
print("\n=== AFTER cartesian_to_EtaPhiPtE ===")
print(f"eta: min={gen_polar_abs[:,:,0].min():.4f}, max={gen_polar_abs[:,:,0].max():.4f}")
print(f"phi: min={gen_polar_abs[:,:,1].min():.4f}, max={gen_polar_abs[:,:,1].max():.4f}")
print(f"pt: min={gen_polar_abs[:,:,2].min():.4f}, max={gen_polar_abs[:,:,2].max():.4f}")
print(f"E: min={gen_polar_abs[:,:,3].min():.4f}, max={gen_polar_abs[:,:,3].max():.4f}")

# Check the actual conversion formula
print("\n=== MANUAL CONVERSION CHECK ===")
x, y, z = samples[:,:,0], samples[:,:,1], samples[:,:,2]
pt_manual = torch.sqrt(x**2 + y**2)
print(f"pt (manual): min={pt_manual.min():.4f}, max={pt_manual.max():.4f}, mean={pt_manual.mean():.4f}")

# Check after relative conversion
print("\n=== AFTER EtaPhiPtE_to_relEtaPhiPt ===")
print(f"pt_rel: min={gen_polar_rel[:,:,2].min():.4f}, max={gen_polar_rel[:,:,2].max():.4f}")
# Out:
# === RAW CARTESIAN SAMPLES ===
# x: min=-309.9751, max=747.9202
# y: min=-1549.6542, max=1253.9587
# z: min=-1013.7399, max=1291.3506
#
# === AFTER cartesian_to_EtaPhiPtE ===
# eta: min=-8.0526, max=8.0524
# phi: min=0.0000, max=6.2832
# pt: min=0.0108, max=2017.1798
# E: min=-309.9751, max=747.9202
#
# === MANUAL CONVERSION CHECK ===
# pt (manual): min=0.3089, max=1700.1996, mean=54.3705
#
# === AFTER EtaPhiPtE_to_relEtaPhiPt ===
# pt_rel: min=321.1904, max=1414440192.0000

# %%
# Test if samples might already be relative polar
print("\nIF samples were already relative polar:")
print(f"eta_rel: min={samples[:,:,0].min():.4f}, max={samples[:,:,0].max():.4f}")
print(f"phi_rel: min={samples[:,:,1].min():.4f}, max={samples[:,:,1].max():.4f}")  
print(f"pt_rel: min={samples[:,:,2].min():.4f}, max={samples[:,:,2].max():.4f}")
# Out:
# IF samples were already relative polar:
# eta_rel: min=-309.9751, max=747.9202
# phi_rel: min=-1549.6542, max=1253.9587
# pt_rel: min=-1013.7399, max=1291.3506

# %%
# 1. Check training data scale
import pickle
with open("local_out/2025-11-13_17-21-10--local-run-pod-DBB4D84C-05B8-410A-B892-E7675C7C5BE0/data/x_train.pkl", "rb") as f:
    X_train = pickle.load(f)

print("=== TRAINING DATA ===")
print(f"X_train particles shape: {X_train[:][0].shape}")
print(f"X_train[0] (Cartesian x,y,z): min={X_train[:][0][:,:,:3].min():.4f}, max={X_train[:][0][:,:,:3].max():.4f}")

# 2. Check what gen_initial_distribution produces
from util.distributions import gen_initial_distribution
import torch

x_0 = gen_initial_distribution(
    batch_size=10,
    num_particles=30,
    prior_dist='isotropic_com',  # or whatever you use
    device='cpu'
)

print("\n=== INITIAL DISTRIBUTION x_0 ===")
print(f"x_0 shape: {x_0.shape}")
print(f"x_0: min={x_0.min():.4f}, max={x_0.max():.4f}")
print(f"x_0 mean: {x_0.mean():.4f}, std: {x_0.std():.4f}")
# Out:
# === TRAINING DATA ===
# X_train particles shape: torch.Size([124076, 30, 4])
# X_train[0] (Cartesian x,y,z): min=-1.4533, max=0.9978
#
# === INITIAL DISTRIBUTION x_0 ===
# x_0 shape: torch.Size([10, 30, 4])
# x_0: min=-1.8427, max=2.4201
# x_0 mean: 0.2638, std: 0.7307
